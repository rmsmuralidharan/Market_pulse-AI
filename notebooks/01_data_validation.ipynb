# %%
import pandas as pd

# %%
df = pd.read_csv('..//project_data//raw//nifty50//nifty50_raw.csv')
df.head()
# Out:
#    Unnamed: 0        Date     Adj Close         Close          High  \
# 0           0  2021-08-13  16529.099609  16529.099609  16543.599609
# 1           1  2021-08-16  16563.050781  16563.050781  16589.400391
# 2           2  2021-08-17  16614.599609  16614.599609  16628.550781
# 3           3  2021-08-18  16568.849609  16568.849609  16701.849609
# 4           4  2021-08-20  16450.500000  16450.500000  16509.550781
#
#             Low          Open  Volume
# 0  16376.299805  16385.699219  321900
# 1  16480.750000  16518.400391  254000
# 2  16495.400391  16545.250000  297400
# 3  16535.849609  16691.949219  251800
# 4  16376.049805  16382.500000  350800

# %%
import os
print(os.getcwd())
# Out:
# d:\MarketPulse-AI\notebooks

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Adj Close', 'Close', 'High', 'Low', 'Open',
#        'Volume'],
#       dtype='str')

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.columns.to_list()
# Out:
# ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']

# %%
df.shape
# Out:
# (1235, 7)

# %%
df.isnull().sum()
# Out:
# Date         0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1235 non-null   str
#  1   Adj Close  1235 non-null   float64
#  2   Close      1235 non-null   float64
#  3   High       1235 non-null   float64
#  4   Low        1235 non-null   float64
#  5   Open       1235 non-null   float64
#  6   Volume     1235 non-null   int64
# dtypes: float64(5), int64(1), str(1)
# memory usage: 67.7 KB

# %%
df.empty
# Out:
# False

# %%
columns = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']

missing_cols = [col for col in columns if col not in df.columns]
print('missing_columns:', missing_cols)

validation_status = len(missing_cols) == 0 and not df.empty
print("validation status:", validation_status)
# Out:
# missing_columns: []
# validation status: True

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Date'] = pd.to_datetime(df['Date'])

print('start_date:', df['Date'].min())
print('end date:', df['Date'].max())
# Out:
# start_date: 2021-08-13 00:00:00
# end date: 2026-08-13 00:00:00

# %%
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())
# Out:
# Shape: (1235, 7)
#
# Columns:
# ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
#
# Data types:
# Date         datetime64[us]
# Adj Close           float64
# Close               float64
# High                float64
# Low                 float64
# Open                float64
# Volume                int64
# dtype: object
#
# Missing values:
# Date         0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64
#
# Duplicate rows:
# 0

# %%
df["Date"] = pd.to_datetime(df["Date"])

print("\nDuplicate dates:")
print(df["Date"].duplicated().sum())

print("\nDates sorted:")
print(df["Date"].is_monotonic_increasing)
# Out:
# Duplicate dates:
# 0
#
# Dates sorted:
# True

# %%
price_columns = ["Open", "High", "Low", "Close"]

for column in price_columns:
    print(
        column,
        "invalid values:",
        (df[column] <= 0).sum()
    )
# Out:
# Open invalid values: 0
# High invalid values: 0
# Low invalid values: 0
# Close invalid values: 0

# %%
print(df[["Open", "High", "Low", "Close"]].dtypes)
# Out:
# Open     float64
# High     float64
# Low      float64
# Close    float64
# dtype: object

# %%
import pandas as pd
df = pd.read_csv(
    "../project_data/processed/nifty50/nifty50_transformed.csv"
)

print(df.shape)
print(df.head())
print(df.tail())
print(df["Target"].value_counts())
# Out:
# (1234, 7)
#          Date          Open          High           Low         Close  Volume  \
# 0  2021-08-13  16385.699219  16543.599609  16376.299805  16529.099609  321900
# 1  2021-08-16  16518.400391  16589.400391  16480.750000  16563.050781  254000
# 2  2021-08-17  16545.250000  16628.550781  16495.400391  16614.599609  297400
# 3  2021-08-18  16691.949219  16701.849609  16535.849609  16568.849609  251800
# 4  2021-08-20  16382.500000  16509.550781  16376.049805  16450.500000  350800
#
#    Target
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
#             Date          Open          High           Low         Close  \
# 1229  2026-08-06  24641.000000  24677.050781  24604.150391  24636.000000
# 1230  2026-08-07  24538.900391  24630.400391  24522.750000  24570.650391
# 1231  2026-08-10  24581.250000  24620.949219  24511.099609  24583.800781
# 1232  2026-08-11  24575.099609  24576.849609  24429.250000  24471.699219
# ...

# %%
import os
print(os.getcwd())
# Out:
# d:\MarketPulse-AI\notebooks

# %%
import pandas as pd

feature_data_path = (
    "../project_data/processed/nifty50/nifty50_features.csv"
)

df = pd.read_csv(feature_data_path)

print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nMissing values:")
print(df.isnull().sum().sum())

print("\nTarget distribution:")
print(df["Target"].value_counts())

print("\nFirst 5 rows:")
print(df.head())

print("\nLast 5 rows:")
print(df.tail())
# Out:
# Shape: (1183, 35)
#
# Columns:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Daily_Return', 'Log_Return', 'High_Low_Range', 'Open_Close_Change', 'SMA_5', 'SMA_20', 'SMA_50', 'EMA_20', 'EMA_50', 'Price_SMA20_Ratio', 'Price_SMA50_Ratio', 'SMA20_SMA50_Ratio', 'Momentum_10', 'RSI_14', 'MACD', 'MACD_Signal', 'MACD_Histogram', 'Volatility_10', 'Volatility_20', 'ATR_14', 'Volume_Change', 'Volume_SMA_20', 'Relative_Volume', 'Return_Lag_1', 'Return_Lag_2', 'Return_Lag_3', 'Return_Lag_5', 'Volume_Lag_1', 'Target']
#
# Missing values:
# 0
#
# Target distribution:
# Target
# 1    620
# 0    563
# Name: count, dtype: int64
#
# First 5 rows:
#          Date          Open          High           Low         Close  Volume  \
# 0  2021-10-26  18154.500000  18310.449219  18099.300781  18268.400391  341400
# 1  2021-10-27  18295.849609  18342.050781  18167.900391  18210.949219  335200
# 2  2021-10-28  18187.650391  18190.699219  17799.449219  17857.250000  374200
# ...

# %%
df = pd.read_csv('../project_data/train/train.csv')
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2021-10-26  18154.500000  18310.449219  18099.300781  18268.400391
# 1    2021-10-27  18295.849609  18342.050781  18167.900391  18210.949219
# 2    2021-10-28  18187.650391  18190.699219  17799.449219  17857.250000
# 3    2021-10-29  17833.050781  17915.849609  17613.099609  17671.650391
# 4    2021-11-01  17783.150391  17954.099609  17697.099609  17929.650391
# ..          ...           ...           ...           ...           ...
# 823  2025-02-24  22609.349609  22668.050781  22518.800781  22553.349609
# 824  2025-02-25  22516.449219  22625.300781  22513.900391  22547.550781
# 825  2025-02-27  22568.949219  22613.300781  22508.400391  22545.050781
# 826  2025-02-28  22433.400391  22450.349609  22104.849609  22124.699219
# 827  2025-03-03  22194.550781  22261.550781  22004.699219  22119.300781
#
#      Volume  Daily_Return  Log_Return  High_Low_Range  Open_Close_Change  ...  \
# ...

# %%
import numpy as np

np.isinf(df.select_dtypes(include=np.number)).sum()
# Out:
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume               0
# Daily_Return         0
# Log_Return           0
# High_Low_Range       0
# Open_Close_Change    0
# SMA_5                0
# SMA_20               0
# SMA_50               0
# EMA_20               0
# EMA_50               0
# Price_SMA20_Ratio    0
# Price_SMA50_Ratio    0
# SMA20_SMA50_Ratio    0
# Momentum_10          0
# RSI_14               0
# MACD                 0
# MACD_Signal          0
# MACD_Histogram       0
# Volatility_10        0
# Volatility_20        0
# ATR_14               0
# Volume_Change        6
# Volume_SMA_20        0
# Relative_Volume      0
# Return_Lag_1         0
# Return_Lag_2         0
# Return_Lag_3         0
# Return_Lag_5         0
# Volume_Lag_1         0
# Target               0
# dtype: int64

# %%
target_column = "Target"

x_train = df.drop(columns=[target_column, "Date"])
y_train = df[target_column]

# %%
x_train.dtypes
# Out:
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume                 int64
# Daily_Return         float64
# Log_Return           float64
# High_Low_Range       float64
# Open_Close_Change    float64
# SMA_5                float64
# SMA_20               float64
# SMA_50               float64
# EMA_20               float64
# EMA_50               float64
# Price_SMA20_Ratio    float64
# Price_SMA50_Ratio    float64
# SMA20_SMA50_Ratio    float64
# Momentum_10          float64
# RSI_14               float64
# MACD                 float64
# MACD_Signal          float64
# MACD_Histogram       float64
# Volatility_10        float64
# Volatility_20        float64
# ATR_14               float64
# Volume_Change        float64
# Volume_SMA_20        float64
# Relative_Volume      float64
# Return_Lag_1         float64
# Return_Lag_2         float64
# Return_Lag_3         float64
# Return_Lag_5         float64
# ...

# %%
x_train.max().sort_values(ascending=False)
# Out:
# Volume_Change                 inf
# Volume_Lag_1         1.006100e+06
# Volume               1.006100e+06
# Volume_SMA_20        4.170900e+05
# High                 2.627735e+04
# Open                 2.624825e+04
# Close                2.621605e+04
# Low                  2.615140e+04
# SMA_5                2.605572e+04
# EMA_20               2.558720e+04
# SMA_20               2.550808e+04
# SMA_50               2.512805e+04
# EMA_50               2.506674e+04
# MACD                 4.510834e+02
# ATR_14               4.503324e+02
# MACD_Signal          4.139853e+02
# MACD_Histogram       1.300943e+02
# RSI_14               1.000000e+02
# Relative_Volume      2.849092e+00
# Price_SMA50_Ratio    1.094770e+00
# Price_SMA20_Ratio    1.060304e+00
# SMA20_SMA50_Ratio    1.055554e+00
# Momentum_10          9.155493e-02
# High_Low_Range       8.673037e-02
# Daily_Return         3.362424e-02
# Return_Lag_3         3.362424e-02
# Return_Lag_5         3.362424e-02
# ...

# %%
df[df["Volume"] == 0][["Date", "Volume"]]
# Out:
#            Date  Volume
# 200  2022-08-16       0
# 350  2023-03-22       0
# 448  2023-08-16       0
# 573  2024-02-19       0
# 600  2024-04-01       0
# 660  2024-07-01       0

# %%
df[df["Volume_Change"] == np.inf][
    ["Date", "Volume", "Volume_Change"]
]
# Out:
#            Date  Volume  Volume_Change
# 201  2022-08-17  262800            inf
# 351  2023-03-23  219200            inf
# 449  2023-08-17  268700            inf
# 574  2024-02-20  295700            inf
# 601  2024-04-02  289500            inf
# 661  2024-07-04  251200            inf

# %%
import pandas as pd

df = pd.read_csv(
    "../project_data/processed/nifty50/nifty50_features.csv"
)

print("Feature dataset:", df.shape)
print("Train:", len(pd.read_csv("../project_data/train/train.csv")))
print("Validation:", len(pd.read_csv("../project_data/validation/validation.csv")))
print("Test:", len(pd.read_csv("../project_data/test/test.csv")))
# Out:
# Feature dataset: (1185, 35)
# Train: 829
# Validation: 177
# Test: 179

# %%
from MarketPulse_AI_project.components.sequence_creation import SequenceCreation
sequence_creator = SequenceCreation(sequence_length=30)

X_train_seq, y_train_seq = sequence_creator.create_sequence(
    x_train_scaled,
    y_train
)

X_validation_seq, y_validation_seq = sequence_creator.create_sequence(
    x_validation_scaled,
    y_validation
)

X_test_seq, y_test_seq = sequence_creator.create_sequence(
    x_test_scaled,
    y_test
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       1 from MarketPulse_AI_project.components.sequence_creation import SequenceCreation
#       2 sequence_creator = SequenceCreation(sequence_length=30)
#       3
#       4 X_train_seq, y_train_seq = sequence_creator.create_sequence(
# ----> 5     x_train_scaled,
#       6     y_train
#       7 )
#       8
#
# NameError: name 'x_train_scaled' is not defined
